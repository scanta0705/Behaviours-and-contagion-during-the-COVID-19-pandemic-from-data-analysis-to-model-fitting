# %% [markdown]
# # Il codice prende i dati di total test e casi per gli stati degli US e poi li carica il FULL_DATA3 in modo da poterli integrare in 'covergaetest+CHI'

# %%
import seaborn as sns
import scipy.stats as stats
import numpy as np
from datetime import date
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import matplotlib.dates as mdates

# %%
dl = pd.read_csv('csv/FULL_DATA3.csv')
df1 = pd.read_csv('csv/time_series_covid19_US.csv') # total cases e totaltest https://github.com/govex/COVID-19/tree/master/data_tables/testing_data

df1=df1[['date', 'state', 'cases_confirmed', 'tests_combined_total']]
df1
df1 = df1.rename(columns={
    'state': 'country',
    'date': 'survey_date',
    'cases_confirmed': 'total_cases',
    'tests_combined_total': 'total_tests'
})
df1['survey_date'] = pd.to_datetime(df1['survey_date'])

# ordina per country e survey_date
df1 = df1.sort_values(['country', 'survey_date']).reset_index(drop=True)
df1 = df1[(df1['survey_date'] >= '2021-05-21') & (df1['survey_date'] <= '2022-06-25')]
print(df1)
# Out:
#       survey_date country  total_cases  total_tests
# 441    2021-05-21      AK      69902.0    2251612.0
# 442    2021-05-22      AK      69902.0    2253889.0
# 443    2021-05-23      AK      69902.0    2256120.0
# 444    2021-05-24      AK      69999.0    2262374.0
# 445    2021-05-25      AK      70052.0    2267721.0
# ...           ...     ...          ...          ...
# 52160  2022-06-21      WY     128684.0    1448270.0
# 52161  2022-06-22      WY     128684.0    1448270.0
# 52162  2022-06-23      WY     128684.0    1448270.0
# 52163  2022-06-24      WY     128684.0    1448270.0
# 52164  2022-06-25      WY     128684.0    1448270.0
#
# [22456 rows x 4 columns]

# %%
US = {
    'AL': 'Alabama',
    'AK': 'Alaska',
    'AZ': 'Arizona',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DE': 'Delaware',
    'DC': 'District of Columbia',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'ME': 'Maine',
    'MD': 'Maryland',
    'MA': 'Massachusetts',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MS': 'Mississippi',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NE': 'Nebraska',
    'NV': 'Nevada',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NY': 'New York',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VT': 'Vermont',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WV': 'West Virginia',
    'WI': 'Wisconsin',
    'WY': 'Wyoming',
    'PR': 'Puerto Rico',
    'VI': 'Virgin Islands',
    'GU': 'Guam',
    'MP': 'Northern Mariana Islands',
    'AS': 'American Samoa',
    'UM': 'U.S. Minor Outlying Islands',
    'FM': 'Federated States of Micronesia',
    'MH': 'Marshall Islands',
    'PW': 'Palau'
}

df1['country'] = df1['country'].map(US).fillna(df1['country'])
print(df1)
# Out:
#       survey_date  country  total_cases  total_tests
# 441    2021-05-21   Alaska      69902.0    2251612.0
# 442    2021-05-22   Alaska      69902.0    2253889.0
# 443    2021-05-23   Alaska      69902.0    2256120.0
# 444    2021-05-24   Alaska      69999.0    2262374.0
# 445    2021-05-25   Alaska      70052.0    2267721.0
# ...           ...      ...          ...          ...
# 52160  2022-06-21  Wyoming     128684.0    1448270.0
# 52161  2022-06-22  Wyoming     128684.0    1448270.0
# 52162  2022-06-23  Wyoming     128684.0    1448270.0
# 52163  2022-06-24  Wyoming     128684.0    1448270.0
# 52164  2022-06-25  Wyoming     128684.0    1448270.0
#
# [22456 rows x 4 columns]

# %%
us = {
    'al': 'Alabama',
    'ak': 'Alaska',
    'az': 'Arizona',
    'ar': 'Arkansas',
    'ca': 'California',
    'co': 'Colorado',
    'ct': 'Connecticut',
    'de': 'Delaware',
    'dc': 'District of Columbia',
    'fl': 'Florida',
    'ga': 'Georgia',
    'hi': 'Hawaii',
    'id': 'Idaho',
    'il': 'Illinois',
    'in': 'Indiana',
    'ia': 'Iowa',
    'ks': 'Kansas',
    'ky': 'Kentucky',
    'la': 'Louisiana',
    'me': 'Maine',
    'md': 'Maryland',
    'ma': 'Massachusetts',
    'mi': 'Michigan',
    'mn': 'Minnesota',
    'ms': 'Mississippi',
    'mo': 'Missouri',
    'mt': 'Montana',
    'ne': 'Nebraska',
    'nv': 'Nevada',
    'nh': 'New Hampshire',
    'nj': 'New Jersey',
    'nm': 'New Mexico',
    'ny': 'New York',
    'nc': 'North Carolina',
    'nd': 'North Dakota',
    'oh': 'Ohio',
    'ok': 'Oklahoma',
    'or': 'Oregon',
    'pa': 'Pennsylvania',
    'ri': 'Rhode Island',
    'sc': 'South Carolina',
    'sd': 'South Dakota',
    'tn': 'Tennessee',
    'tx': 'Texas',
    'ut': 'Utah',
    'vt': 'Vermont',
    'va': 'Virginia',
    'wa': 'Washington',
    'wv': 'West Virginia',
    'wi': 'Wisconsin',
    'wy': 'Wyoming',
    'pr': 'Puerto Rico',
    'vi': 'Virgin Islands',
    'gu': 'Guam',
    'mp': 'Northern Mariana Islands',
    'as': 'American Samoa',
    'um': 'U.S. Minor Outlying Islands',
    'fm': 'Federated States of Micronesia',
    'mh': 'Marshall Islands',
    'pw': 'Palau'
}

# %%
dl["total_cases"] = None
dl["total_tests"] = None
dl
# Out:
#              country survey_date  pct_mask  pct_worried_catch_covid  \
# 0          Argentina  2021-05-21  0.883037                 0.842583
# 1          Argentina  2021-05-22  0.897337                 0.836449
# 2          Argentina  2021-05-23  0.878700                 0.820045
# 3          Argentina  2021-05-24  0.868005                 0.850276
# 4          Argentina  2021-05-25  0.883632                 0.826286
# ...              ...         ...       ...                      ...
# 35161  West Virginia  2022-06-21  0.190077                 0.330420
# 35162  West Virginia  2022-06-22  0.178180                 0.327251
# 35163  West Virginia  2022-06-23  0.182700                 0.319211
# 35164  West Virginia  2022-06-24  0.187612                 0.316179
# 35165  West Virginia  2022-06-25  0.188405                 0.341082
#
#        pct_belief_masking_effective  pct_received_news_local_health  \
# 0                          0.914011                        0.397329
# ...

# %%
df1
# Out:
#       survey_date  country  total_cases  total_tests
# 441    2021-05-21   Alaska      69902.0    2251612.0
# 442    2021-05-22   Alaska      69902.0    2253889.0
# 443    2021-05-23   Alaska      69902.0    2256120.0
# 444    2021-05-24   Alaska      69999.0    2262374.0
# 445    2021-05-25   Alaska      70052.0    2267721.0
# ...           ...      ...          ...          ...
# 52160  2022-06-21  Wyoming     128684.0    1448270.0
# 52161  2022-06-22  Wyoming     128684.0    1448270.0
# 52162  2022-06-23  Wyoming     128684.0    1448270.0
# 52163  2022-06-24  Wyoming     128684.0    1448270.0
# 52164  2022-06-25  Wyoming     128684.0    1448270.0
#
# [22456 rows x 4 columns]

# %%
# unisci i due DataFrame sulla chiave comune
dl.set_index(["country", "survey_date"], inplace=True)
df1.set_index(["country", "survey_date"], inplace=True)
dl.update(df1[["total_cases", "total_tests"]]) # aggiorna solo le colonne presenti in df1
dl.reset_index(inplace=True)   # torna al formato originale
df1.reset_index(inplace=True)

# %%
dl
# Out:
#              country survey_date  pct_mask  pct_worried_catch_covid  \
# 0          Argentina  2021-05-21  0.883037                 0.842583
# 1          Argentina  2021-05-22  0.897337                 0.836449
# 2          Argentina  2021-05-23  0.878700                 0.820045
# 3          Argentina  2021-05-24  0.868005                 0.850276
# 4          Argentina  2021-05-25  0.883632                 0.826286
# ...              ...         ...       ...                      ...
# 35161  West Virginia  2022-06-21  0.190077                 0.330420
# 35162  West Virginia  2022-06-22  0.178180                 0.327251
# 35163  West Virginia  2022-06-23  0.182700                 0.319211
# 35164  West Virginia  2022-06-24  0.187612                 0.316179
# 35165  West Virginia  2022-06-25  0.188405                 0.341082
#
#        pct_belief_masking_effective  pct_received_news_local_health  \
# 0                          0.914011                        0.397329
# ...

# %%
dl.to_csv('csv/full_data3_con_usa.csv', index=False) #conteine total test e total cases degli usa per fare le figure dopo contenneti anche gli USA states e non solo il mondo
